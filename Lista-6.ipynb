# %% [markdown]
# <a href="https://colab.research.google.com/github/carlosh53421/demo/blob/master/Lista-6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Disciplina:Probabilidade e estatística 
#Aluno:Carlos Henrique Pereira Lima #Matrícula:20114290103
#Lista 6

# Questão 1
print('Questão 1')
import pandas as pd
data = {'Matemática': [60, 58, 73, 51, 54, 75, 48, 72, 75, 83, 62, 52],'Música': [80, 62, 70, 83, 62, 92, 79, 88, 54, 82, 64, 69]}
df = pd.DataFrame (data, columns = ['Matemática','Música'])
Correlação = df.corr()
print(Correlação)
print(  )
#Com os dados fornecidos pela questão foi criado a variavel data que contem os dados de aptidão das crianças, e com isso podemos fazer o coeficiente da correlação.
# Questão 2 
#a)0 a 0.3 positivo ou negativo indica uma correlação desprezível.Assim a relação entre a idade da edição e o número de páginas é desprezível por ser 0,207.
print('Questão 2')
print('a)0 a 0.3 positivo ou negativo indica uma correlação desprezível.Assim a relação entre a idade da edição e o número de páginas é desprezível por ser 0,207.')
print()
# Questão 3
print('Questão 3')
import pandas as pd 
data = {'x': [2, 3, 4, 5, 4, 6, 7, 8, 8, 10],'y': [48, 50, 56, 52, 43, 60, 62, 58, 64, 72]}
df = pd.DataFrame (data, columns = ['x','y'])
Correlação = df.corr()
print(Correlação)
print()
#Com os dados fornecidos pela questão foi criado a variavel data que contem os dados dos anos de serviço e o número de clientes. Analisando 
#o resultado do coeficiente da correlação vamos obter uma correlação positiva forte:0.876795
# Questão 4
print('Questão 4')
import pandas as pd 
data = {'x': [12, 16, 18, 20, 28, 30, 40, 48, 50, 54], 'y': [7.2, 7.4, 7.0, 6.5, 6.6, 6.7, 6.0, 5.6, 6.0, 5.5]}
df = pd.DataFrame (data, columns = ['x','y'])
Correlação = df.corr()
print(Correlação)
# O coeficiente de correlação da renda bruta mensal em relação a renda bruta anula gasta em assistência médica é correlação negativa forte:-0.940463.
print()
# Questão 05
print('Qquestão 5')
print('Conjunto 1')
# Conjunto 1
import statistics
x = [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5]
y = [8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68]
print('Média de X:', statistics.mean(x),'Média de Y:', round(statistics.mean(y),2))
print('Desvio padrão de X:', round(statistics.stdev(x),2),'Desvio padrão de Y:', round(statistics.stdev(y),2))
import pandas as pd
data = {'x': [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5], 'y': [8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68]}
df = pd.DataFrame (data, columns = ['x','y'])
Correlação = df.corr()
print('Coeficiente de correlação de X e Y:', Correlação)
print()
# Conjunto 2
print('Conjunto 2')
import statistics
x = [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5]
y = [9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74]
print('Média de X:', statistics.mean(x),'Média de Y:', round(statistics.mean(y),2))
print('Desvio padrão de X:', round(statistics.stdev(x),2),'Desvio padrão de Y:', round(statistics.stdev(y),2))
import pandas as pd
data = {'x': [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5], 'y': [9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74]}
df = pd.DataFrame (data, columns = ['x','y'])
Corr = df.corr()
print('Coeficiente de correlação de X e Y:', Corr)
print()
# Conjunto 3
print('Conjunto 3')
import statistics
x = [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5]
y = [7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15, 6.42, 5.73]
print('Média de X:', statistics.mean(x),'Média de Y:', round(statistics.mean(y),2))
print('Desvio padrão de X:', round(statistics.stdev(x),2),'Desvio padrão de Y:', round(statistics.stdev(y),2))
import pandas as pd
data = {'x': [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5], 'y': [7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15, 6.42, 5.73]}
df = pd.DataFrame (data, columns = ['x','y'])
Correlação = df.corr()
print('Coeficiente de correlação de X e Y:', Correlação)
print()
# Conjunto 4
print('Conjunto 4')
import statistics
x = [8, 8, 8, 8, 8, 8, 8, 19, 8, 8, 8]
y = [6.58, 5.76, 7.71, 8.84, 8.47, 7.04, 5.25, 12.50, 5.56, 7.91, 6.89]
print('Média de X:', statistics.mean(x),'Média de Y:', round(statistics.mean(y),2))
print('Desvio padrão de X:', round(statistics.stdev(x),2),'Desvio padrão de Y:', round(statistics.stdev(y),2))
import pandas as pd
data = {'x': [8, 8, 8, 8, 8, 8, 8, 19, 8, 8, 8], 'y': [6.58, 5.76, 7.71, 8.84, 8.47, 7.04, 5.25, 12.50, 5.56, 7.91, 6.89]}
df = pd.DataFrame (data, columns = ['x','y'])
Correlação = df.corr()
print('Coeficiente de correlação de X e Y:', Correlação)
print()
# Todos os conjuntos apresentam um coeficiente de correlação positiva forte.
# Com os dados fornecidos pelo exercicio a variavel data foi criada e seus valores estão representados nas colunas X e Y, usamos essa váriavel e os valores presentes nos conjuntos para calcularmos a 
# média e o desvio padrão de cada conjunto na questão A ,e na questão B  calculamos o coeficiente de correlação de cada conjunto.
# Questão 6
print('Questão 6')
import pandas as pd
data = {'Produtividade': [100, 102, 105, 108, 112, 120], 'Alimentação': [4, 5, 1, 3, 6, 2]}
df = pd.DataFrame (data, columns = ['Produtividade','Alimentação'])
Correlação = df.corr()
print('Coeficiente de correlação linear:')
print(Correlação)
print()
#O diagrama em relação ao coeficiente de correlação entre produtividade e alimentação está correto, porque no diagrama mostra uma diminuição da alimentação em relação a produtividade e no 
# calculo é mostrado que o valor corresponde a uma correlação desprezível fraca:-0.196822.
import pandas as pd
data = {'Produtividade': [100, 102, 105, 108, 112, 120], 'Exercícios': [1, 3, 2, 4, 5, 6]}
df = pd.DataFrame (data, columns = ['Produtividade','Exercícios'])
Correlação = df.corr()
print('Coeficiente de correlação linear:')
print(Correlação)
print()
#O diagrama em relação ao coeficiente de correlação entre produtividade e exercícios está correto, porque no diagrama mostra um aumento de exercícios em relação a produtividade e no 
# calculo é mostrado que o valor corresponde a uma correlação positiva forte:0.925791.
import pandas as pd
data = {'Produtividade': [100, 102, 105, 108, 112, 120], 'Rodízio': [3, 1, 2, 6, 4, 5]}
df = pd.DataFrame (data, columns = ['Produtividade','Rodízio'])
Correlação = df.corr()
print('Coeficiente de correlação linear:')
print(Correlação)
#O diagrama em relação ao coeficiente de correlação entre produtividade e rodízio está correto, porque no diagrama mostra um aumento de rodízio em relação a produtividade e no 
# calculo é mostrado que o valor corresponde a uma correlação positiva moderada:0.634204.
# Out:
# Questão 1
#             Matemática    Música
# Matemática    1.000000  0.169146
# Música        0.169146  1.000000
#
# Questão 2
# a)0 a 0.3 positivo ou negativo indica uma correlação desprezível.Assim a relação entre a idade da edição e o número de páginas é desprezível por ser 0,207.
#
# Questão 3
#           x         y
# x  1.000000  0.876795
# y  0.876795  1.000000
#
# Questão 4
#           x         y
# x  1.000000 -0.940463
# y -0.940463  1.000000
#
# Qquestão 5
# Conjunto 1
# Média de X: 9 Média de Y: 7.5
# Desvio padrão de X: 3.32 Desvio padrão de Y: 2.03
# Coeficiente de correlação de X e Y:           x         y
# x  1.000000  0.816421
# y  0.816421  1.000000
#
# Conjunto 2
# Média de X: 9 Média de Y: 7.5
# Desvio padrão de X: 3.32 Desvio padrão de Y: 2.03
# Coeficiente de correlação de X e Y:           x         y
# x  1.000000  0.816237
# y  0.816237  1.000000
#
# Conjunto 3
# Média de X: 9 Média de Y: 7.5
# Desvio padrão de X: 3.32 Desvio padrão de Y: 2.03
# ...
